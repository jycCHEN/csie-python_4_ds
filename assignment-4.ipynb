# %%
# %run assignment-1.ipynb
df=get_top_200()

# %%
dfOBU=df[df['company'].str.find('KY') != -1]
answer1= len(dfOBU)

# %%
import pandas as pd
dfNotOBU=df[df.company.str.find('KY') == -1]

dfNotOBU.loc[:, 'price']= pd.to_numeric(dfNotOBU.price)
dfNotOBU.sort_values('price', ascending=False, inplace=True)
# Out:
# D:\ProgramFiles\Anaconda3\lib\site-packages\pandas\core\indexing.py:630: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# D:\ProgramFiles\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
print('There are ', answer1, 'OBU companies')
dfNotOBU
# Out:
# There are  28 OBU companies
#     ticker company   price type
# 0     3008     大立光  5180.0   上市
# 1     2327      國巨   840.0   上市
# 100   5274      信驊   818.0   上櫃
# 101   6510      精測   782.0   上櫃
# 102   1565      精華   651.0   上櫃
# 103   8436      大江   554.0   上櫃
# 3     6409      旭隼   538.0   上市
# 104   6488     環球晶   523.0   上櫃
# 4     5269      祥碩   487.5   上市
# 5     3406     玉晶光   476.5   上市
# 106   3563      牧德   470.5   上櫃
# 6     2059      川湖   427.0   上市
# 8     6414      樺漢   383.0   上市
# 9     2492     華新科   382.0   上市
# 107   6548     長華科   380.0   上櫃
# 10    2474      可成   376.0   上市
# 11    1476      儒鴻   349.0   上市
# 12    2912     統一超   330.0   上市
# 108   3529      力旺   328.0   上櫃
# 109   5904      寶雅   327.0   上櫃
# 14    2231      為升   308.5   上市
# 15    2049      上銀   307.5   上市
# 16    3443      創意   306.0   上市
# 110   3081      聯亞   285.0   上櫃
# 112   5287      數字   276.5   上櫃
# 20    2207     和泰車   268.0   上市
# 21    8464      億豐   267.0   上市
# ...
